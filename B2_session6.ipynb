# %%
# Machine learning improves by measuring errors and correcting itself step by step

# %%
#feature
#label
#prediction problem
#conclusion from the visible data
# feature: GDP per capita
# Label: Life expectancy

# Prediction Problem: Regression (predict life expectancy from GDP)

# Conclusion: Life expectancy increases with GDP, but growth slows at higher income levels.

# %%
#Face unlock-- classification
#predicting land prices-- regression
#google photos use what to define faces-- classification
#weather forecast-- regression

#classification:

#student results--
JEE MAINS (marks to rank)

XYZ-marks--2

#feature
percentile
score
rank
category
study hours per day
no of questions attempted
shifts
no students attempted
difficulty level of shift

percentile- raw marks

# %%
#colour difference
#position
